# %% [markdown]
# Installation modul

# %%
# !pip install python-Levenshtein
# !pip install bert-serving-server bert-serving-client
# !pip install transformers
# !pip install pandas
# !pip install --upgrade pip
# !pip install tensorflow
# !pip install tf-nightly
# !pip install transformers
# !py -3.9 -m pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
# !py -3.9 -m pip install -Uq sentence-transformers --user

# %% [markdown]
# Load data

# %%
import pandas as pd 
import os

# %%
files = os.listdir('dataset/')
files = files[0:3]
files
# Out:
# ['S08_question_answer_pairs.txt',
#  'S09_question_answer_pairs.txt',
#  'S10_question_answer_pairs.txt']

# %%
df = pd.DataFrame()

for file in files:
  sub_df = pd.read_csv('dataset/' + file, sep='\t', encoding='latin-1').drop_duplicates(subset='Question')
  df = pd.concat([df, sub_df], ignore_index=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2463 entries, 0 to 2462
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ï»¿ArticleTitle           1631 non-null   object
#  1   Question                  2461 non-null   object
#  2   Answer                    2188 non-null   object
#  3   DifficultyFromQuestioner  1570 non-null   object
#  4   DifficultyFromAnswerer    2185 non-null   object
#  5   ArticleFile               2461 non-null   object
#  6   ArticleTitle              832 non-null    object
# dtypes: object(7)
# memory usage: 134.8+ KB

# %%
df.drop('ArticleTitle', axis=1, inplace=True)
df.rename(columns={'ï»¿ArticleTitle':'ArticleTitle'}, inplace=True)
df
# Out:
#          ArticleTitle                                           Question  \
# 0     Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...
# 1     Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...
# 2     Abraham_Lincoln                   Did his mother die of pneumonia?
# 3     Abraham_Lincoln      How many long was Lincoln's formal education?
# 4     Abraham_Lincoln       When did Lincoln begin his political career?
# ...               ...                                                ...
# 2458              NaN                                What do zebras eat?
# 2459              NaN                        What are zebras hunted for?
# 2460              NaN          What areas do the Grevy's Zebras inhabit?
# 2461              NaN  Which species of zebra is known as the common ...
# 2462              NaN                     At what age can a zebra breed?
#
#                                                  Answer  \
# 0                                                   yes
# 1                                                   yes
# 2                                                    no
# 3                                             18 months
# 4                                                  1832
# ...                                                 ...
# 2458                                       mainly grass
# 2459                             mainly for their skins
# 2460  semi-arid grasslands of Ethiopia and northern ...
# 2461  Plains Zebra (Equus quagga, formerly Equus bur...
# 2462                                        five or six
#
#      DifficultyFromQuestioner DifficultyFromAnswerer  ArticleFile
# 0                        easy                   easy  S08_set3_a4
# 1                        easy                 medium  S08_set3_a4
# 2                        easy                 medium  S08_set3_a4
# 3                      medium                   easy  S08_set3_a4
# 4                      medium                   easy  S08_set3_a4
# ...                       ...                    ...          ...
# 2458                   medium                   hard  S10_set1_a9
# 2459                   medium                 medium  S10_set1_a9
# 2460                     hard                   hard  S10_set1_a9
# 2461                     hard                 medium  S10_set1_a9
# 2462                     hard                 medium  S10_set1_a9
#
# [2463 rows x 6 columns]

# %% [markdown]
# Data cleaning

# %%
df.dropna(subset=['Question'], inplace=True)
df.dropna(subset=['Answer'], inplace=True)
df.dropna(subset=['ArticleTitle'], inplace=True)
df = df[~df['Question'].str.contains('#')]
df = df[~df['Answer'].isin(['no','yes','Yes','No','No,','Yes,','No.','Yes.','yes.','no.'])]

# %% [markdown]
# modeling

# %%
from transformers import pipeline
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
model = pipeline('question-answering', model='distilbert-base-cased-distilled-squad')
# Out:
# Downloading model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# c:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\huggingface_hub\file_download.py:133: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\user\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
def AnswerQuestion(q, article):
    folder = 'dataset/text_data/'
    files = df[df['ArticleTitle'] == article]['ArticleFile'].unique()[0] + '.txt.clean'
    path = os.path.join(folder, files)
    
    with open(path, 'r', errors='ignore') as my_files:
        context = my_files.read().replace('\n', '')
        # print(context)

    return model(q, context)

AnswerQuestion('Who made Volta a count?', 'Alessandro_Volta')
# Out:
# {'score': 0.7745566964149475, 'start': 4404, 'end': 4412, 'answer': 'Napoleon'}

# %%
sample = df.sample(30)
sample['AnswerFromModel'] = sample.apply(lambda x: AnswerQuestion(x['Question'], x['ArticleTitle']), axis=1)
sample['ModelingAnswer'] = sample['AnswerFromModel'].apply(lambda x: x['answer'])
sample['ModelingScore'] = sample['AnswerFromModel'].apply(lambda x: x['score'])
sample.drop('AnswerFromModel', axis=1, inplace=True)
sample.head()
# Out:
#      ArticleTitle                                           Question  \
# 165        Canada  In addition to Port Royal, where else did Samu...
# 840       Romania  What are approximately 42,000 years old and ha...
# 870     Singapore               Where is the National Orchid Garden?
# 875     Singapore    What is the punishment for first-degree murder?
# 1377   James_Watt                         James Watt was born where?
#
#                                                  Answer  \
# 165                                         Quebec City
# 840   the remains (the lower jaw) of the oldest mode...
# 870                          Singapore Botanic Gardens.
# 875   There are laws which allow capital punishment ...
# 1377          Greenock, a seaport on the Firth of Clyde
#
#      DifficultyFromQuestioner DifficultyFromAnswerer  ArticleFile  \
# 165                    medium                 medium  S08_set2_a8
# 840                       NaN                   hard  S08_set2_a7
# 870                    medium                 medium  S08_set2_a2
# 875                      hard                   hard  S08_set2_a2
# 1377                     easy                 medium  S09_set4_a2
#
#                    ModelingAnswer  ModelingScore
# 165                   Quebec City       0.995903
# 840   The remains (the lower jaw)       0.306820
# 870                     Singapore       0.594911
# 875            capital punishment       0.874122
# 1377                       London       0.967558

# %%
sample.drop('DifficultyFromQuestioner', axis=1, inplace=True)
sample.drop('DifficultyFromAnswerer', axis=1, inplace=True)
# sample.drop('ArticleFile', axis=1, inplace=True)
sample.head()
# Out:
#      ArticleTitle                                           Question  \
# 165        Canada  In addition to Port Royal, where else did Samu...
# 840       Romania  What are approximately 42,000 years old and ha...
# 870     Singapore               Where is the National Orchid Garden?
# 875     Singapore    What is the punishment for first-degree murder?
# 1377   James_Watt                         James Watt was born where?
#
#                                                  Answer  ArticleFile  \
# 165                                         Quebec City  S08_set2_a8
# 840   the remains (the lower jaw) of the oldest mode...  S08_set2_a7
# 870                          Singapore Botanic Gardens.  S08_set2_a2
# 875   There are laws which allow capital punishment ...  S08_set2_a2
# 1377          Greenock, a seaport on the Firth of Clyde  S09_set4_a2
#
#                    ModelingAnswer  ModelingScore
# 165                   Quebec City       0.995903
# 840   The remains (the lower jaw)       0.306820
# 870                     Singapore       0.594911
# 875            capital punishment       0.874122
# 1377                       London       0.967558

# %% [markdown]
# Compare Model Answering

# %%
from sentence_transformers import util, SentenceTransformer

# %%
def SimilarityAnswer(answ, model_answ, model):
    answ_em = model.encode(answ, convert_to_tensor=True)
    model_answ_em = model.encode(model_answ, convert_to_tensor=True)

    return util.pytorch_cos_sim(answ_em, model_answ_em).item()

# %%
model_st = SentenceTransformer('sentence-transformers/all-miniLM-L6-v2')
sample['SimilarityAnswer'] = sample.apply(lambda x: SimilarityAnswer(x['Answer'], x['ModelingAnswer'], model_st), axis=1)
sample.sort_values(by='SimilarityAnswer', ascending=False)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
#             ArticleTitle                                           Question  \
# 777           polar_bear                    How heavy is a male polar bear?
# 632        Liechtenstein                 When was the first factory opened?
# 1223          Copenhagen   What transnational bridge was completed in 2000?
# 1444     Michael_Faraday         Who was the sponsor and mentor of Faraday?
# 165               Canada  In addition to Port Royal, where else did Samu...
# 716                otter                     What is an otter's den called?
# 1618              Violin       How many strings does a violin usually have?
# 180               Canada  European books and maps began referring to thi...
# 833              Romania  Who was the first gymnast to score a perfect "...
# 912               turtle                          How do turtles reproduce?
# 839              Romania  Sibiu, a large city in Transylvania, was chose...
# 244             elephant  Why does the phrase 'elephants never forget' h...
# 840              Romania  What are approximately 42,000 years old and ha...
# 416     Grover_Cleveland                                   When did he die?
# 236                Egypt         What is the estimated population of Egypt?
# 953     Ulysses_S._Grant  Who achieved international fame as the leading...
# 875            Singapore    What is the punishment for first-degree murder?
# 870            Singapore               Where is the National Orchid Garden?
# 718                otter  How do otters keep themselves warm without blu...
# 176               Canada          What is the largest country in the world?
# 829              Romania       How many territories joined to form Romania?
# 7        Abraham_Lincoln  When did the Gettysburg address argue that Ame...
# 272              Finland   What body of water lies to the south of Finland?
# 1377          James_Watt                         James Watt was born where?
# 909               turtle  What shape are the eggs of the larest species ...
# 666     Millard_Fillmore              Who got Seward elected to the senate?
# 707                otter                          Where do sea otters live?
# 873            Singapore      Who did Sir Thomas Stamford Raffles work for?
# 892   Theodore_Roosevelt  What did Roosevelt do to improve his physical ...
# 851            Singapore  Did Singapore's standard of living decrease si...
#
#                                                  Answer  ArticleFile  \
# 777                            300-600 kg (660-1320 lb)  S08_set1_a4
# 632                                                1836  S08_set2_a1
# 1223                                     Oresund Bridge  S09_set3_a8
# 1444                             John 'Mad Jack' Fuller  S09_set4_a7
# 165                                         Quebec City  S08_set2_a8
# 716                                                Holt  S08_set1_a7
# 1618                                               four  S09_set2_a2
# 180                                                1545  S08_set2_a8
# 833                                     Nadia ComÄneci  S08_set2_a7
# 912                                       They lay eggs  S08_set1_a9
# 839                                                2007  S08_set2_a7
# 244   it refers literally to elephants supposedly ha...  S08_set1_a5
# 840   the remains (the lower jaw) of the oldest mode...  S08_set2_a7
# 416                                        June 24 1908  S08_set3_a6
# 236                               More than 78 million.  S08_set2_a6
# 953                                               Grant  S08_set3_a5
# 875   There are laws which allow capital punishment ...  S08_set2_a2
# 870                          Singapore Botanic Gardens.  S08_set2_a2
# 718              A layer of air trapped in their fur.    S08_set1_a7
# 176   Canada is the second largest country in the wo...  S08_set2_a8
# 829                                                  2.  S08_set2_a7
# 7                                                  1776  S08_set3_a4
# 272                                 the Gulf of Finland  S08_set2_a4
# 1377          Greenock, a seaport on the Firth of Clyde  S09_set4_a2
# 909                                           Spherical  S08_set1_a9
# 666                                                Weed  S08_set3_a3
# 707   Sea otters (Enhydra lutris) live along the Pac...  S08_set1_a7
# 873                          British East India Company  S08_set2_a2
# 892                          Roosevelt took up exercise  S08_set3_a7
# 851                 No, the standard living was raised.  S08_set2_a2
#
#                                          ModelingAnswer  ModelingScore  \
# 777                            300-600 kg (660-1320 lb)       0.501930
# 632                                                1836       0.952051
# 1223                                     Oresund Bridge       0.951993
# 1444                             John 'Mad Jack' Fuller       0.986463
# 165                                         Quebec City       0.995903
# 716                                                holt       0.893469
# 1618                                               four       0.664392
# 180                                                1545       0.965857
# 833                                     Nadia ComÄƒneci       0.921662
# 912                                            lay eggs       0.055917
# 839                                             2007The       0.996259
# 244     elephants supposedly having an excellent memory       0.453080
# 840                         The remains (the lower jaw)       0.306820
# 416                        March 18 1837   June 24 1908       0.768992
# 236                               a couple of thousands       0.888763
# 953                  Ulysses S. Grant  Ulysses S. Grant       0.778269
# 875                                  capital punishment       0.874122
# 870                                           Singapore       0.594911
# 718   traps a layer of air, and keeps them dry and w...       0.187602
# 176                                        CanadaCanada       0.947160
# 829                                                  42       0.552830
# 7                                     November 19, 1863       0.977124
# 272                                 Barents Sea harbour       0.537658
# 1377                                             London       0.967558
# 909                          slightly soft and leathery       0.799106
# 666                                      Winfield Scott       0.602340
# 707                                         cold waters       0.412723
# 873                                      Thomas Woolner       0.986739
# 892           dissolved forty monopolistic corporations       0.506387
# 851                                       progressively       0.297134
#
#       SimilarityAnswer
# 777           1.000000
# 632           1.000000
# 1223          1.000000
# 1444          1.000000
# 165           1.000000
# 716           1.000000
# 1618          1.000000
# 180           1.000000
# 833           0.953200
# 912           0.877090
# 839           0.842817
# 244           0.834008
# 840           0.790763
# 416           0.735608
# 236           0.663142
# 953           0.612087
# 875           0.600196
# 870           0.566212
# 718           0.512745
# 176           0.498209
# 829           0.432352
# 7             0.334385
# 272           0.308042
# 1377          0.242339
# 909           0.218172
# 666           0.212471
# 707           0.186544
# 873           0.111545
# 892           0.058706
# 851           0.016709

# %%
sample.to_csv('dataset/result.csv', index=False)

# %%
result = pd.read_csv('dataset/result.csv')
result
# Out:
#           ArticleTitle                                           Question  \
# 0               Canada  In addition to Port Royal, where else did Samu...
# 1              Romania  What are approximately 42,000 years old and ha...
# 2            Singapore               Where is the National Orchid Garden?
# 3            Singapore    What is the punishment for first-degree murder?
# 4           James_Watt                         James Watt was born where?
# 5        Liechtenstein                 When was the first factory opened?
# 6     Ulysses_S._Grant  Who achieved international fame as the leading...
# 7               Violin       How many strings does a violin usually have?
# 8              Finland   What body of water lies to the south of Finland?
# 9     Grover_Cleveland                                   When did he die?
# 10              turtle  What shape are the eggs of the larest species ...
# 11     Abraham_Lincoln  When did the Gettysburg address argue that Ame...
# 12              Canada          What is the largest country in the world?
# 13              turtle                          How do turtles reproduce?
# 14             Romania  Sibiu, a large city in Transylvania, was chose...
# 15            elephant  Why does the phrase 'elephants never forget' h...
# 16               otter  How do otters keep themselves warm without blu...
# 17           Singapore  Did Singapore's standard of living decrease si...
# 18     Michael_Faraday         Who was the sponsor and mentor of Faraday?
# 19               Egypt         What is the estimated population of Egypt?
# 20          Copenhagen   What transnational bridge was completed in 2000?
# 21               otter                     What is an otter's den called?
# 22  Theodore_Roosevelt  What did Roosevelt do to improve his physical ...
# 23          polar_bear                    How heavy is a male polar bear?
# 24               otter                          Where do sea otters live?
# 25             Romania  Who was the first gymnast to score a perfect "...
# 26           Singapore      Who did Sir Thomas Stamford Raffles work for?
# 27    Millard_Fillmore              Who got Seward elected to the senate?
# 28              Canada  European books and maps began referring to thi...
# 29             Romania       How many territories joined to form Romania?
#
#                                                Answer  ArticleFile  \
# 0                                         Quebec City  S08_set2_a8
# 1   the remains (the lower jaw) of the oldest mode...  S08_set2_a7
# 2                          Singapore Botanic Gardens.  S08_set2_a2
# 3   There are laws which allow capital punishment ...  S08_set2_a2
# 4           Greenock, a seaport on the Firth of Clyde  S09_set4_a2
# 5                                                1836  S08_set2_a1
# 6                                               Grant  S08_set3_a5
# 7                                                four  S09_set2_a2
# 8                                 the Gulf of Finland  S08_set2_a4
# 9                                        June 24 1908  S08_set3_a6
# 10                                          Spherical  S08_set1_a9
# 11                                               1776  S08_set3_a4
# 12  Canada is the second largest country in the wo...  S08_set2_a8
# 13                                      They lay eggs  S08_set1_a9
# 14                                               2007  S08_set2_a7
# 15  it refers literally to elephants supposedly ha...  S08_set1_a5
# 16             A layer of air trapped in their fur.    S08_set1_a7
# 17                No, the standard living was raised.  S08_set2_a2
# 18                             John 'Mad Jack' Fuller  S09_set4_a7
# 19                              More than 78 million.  S08_set2_a6
# 20                                     Oresund Bridge  S09_set3_a8
# 21                                               Holt  S08_set1_a7
# 22                         Roosevelt took up exercise  S08_set3_a7
# 23                           300-600 kg (660-1320 lb)  S08_set1_a4
# 24  Sea otters (Enhydra lutris) live along the Pac...  S08_set1_a7
# 25                                    Nadia ComÄneci  S08_set2_a7
# 26                         British East India Company  S08_set2_a2
# 27                                               Weed  S08_set3_a3
# 28                                               1545  S08_set2_a8
# 29                                                 2.  S08_set2_a7
#
#                                        ModelingAnswer  ModelingScore  \
# 0                                         Quebec City       0.995903
# 1                         The remains (the lower jaw)       0.306820
# 2                                           Singapore       0.594911
# 3                                  capital punishment       0.874122
# 4                                              London       0.967558
# 5                                                1836       0.952051
# 6                  Ulysses S. Grant  Ulysses S. Grant       0.778269
# 7                                                four       0.664392
# 8                                 Barents Sea harbour       0.537658
# 9                        March 18 1837   June 24 1908       0.768992
# 10                         slightly soft and leathery       0.799106
# 11                                  November 19, 1863       0.977124
# 12                                       CanadaCanada       0.947160
# 13                                           lay eggs       0.055917
# 14                                            2007The       0.996259
# 15    elephants supposedly having an excellent memory       0.453080
# 16  traps a layer of air, and keeps them dry and w...       0.187602
# 17                                      progressively       0.297134
# 18                             John 'Mad Jack' Fuller       0.986463
# 19                              a couple of thousands       0.888763
# 20                                     Oresund Bridge       0.951993
# 21                                               holt       0.893469
# 22          dissolved forty monopolistic corporations       0.506387
# 23                           300-600 kg (660-1320 lb)       0.501930
# 24                                        cold waters       0.412723
# 25                                    Nadia ComÄƒneci       0.921662
# 26                                     Thomas Woolner       0.986739
# 27                                     Winfield Scott       0.602340
# 28                                               1545       0.965857
# 29                                                 42       0.552830
#
#     SimilarityAnswer
# 0           1.000000
# 1           0.790763
# 2           0.566212
# 3           0.600196
# 4           0.242339
# 5           1.000000
# 6           0.612087
# 7           1.000000
# 8           0.308042
# 9           0.735608
# 10          0.218172
# 11          0.334385
# 12          0.498209
# 13          0.877090
# 14          0.842817
# 15          0.834008
# 16          0.512745
# 17          0.016709
# 18          1.000000
# 19          0.663142
# 20          1.000000
# 21          1.000000
# 22          0.058706
# 23          1.000000
# 24          0.186544
# 25          0.953200
# 26          0.111545
# 27          0.212471
# 28          1.000000
# 29          0.432352
